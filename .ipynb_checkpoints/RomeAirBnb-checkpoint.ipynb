# %% [markdown]
# # The Roman Empire of Airbnb

# %% [markdown]
# ## Import important libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from shapely.geometry import Point

# %% [markdown]
# ## Import datasets

# %%
df_listings = pd.read_csv("listings_summarize.csv")
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN                NaN
# 37648                  0         NaN                NaN
# 37649                  0         NaN                NaN
# 37650                  0         NaN                NaN
# 37651                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license
# 0                          0                 NaN
# 1                         30  IT058091C29VJSIZQZ
# 2                         13  it058091c2kv6epw8f
# 3                         21  IT058091C20YD35BX2
# 4                          0  IT058091C20YD35BX2
# ...                      ...                 ...
# 37647                      0  IT058091B4XPH449TB
# 37648                      0  IT058091C2RGTLCJNR
# 37649                      0  IT058091C2DZHIDY6A
# 37650                      0  it058091c2rf3ps25z
# 37651                      0  IT058091C26JO2EDQQ
#
# [37652 rows x 18 columns]

# %%
df_reviews = pd.read_csv("listings_summarize.csv")
df_reviews
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN                NaN
# 37648                  0         NaN                NaN
# 37649                  0         NaN                NaN
# 37650                  0         NaN                NaN
# 37651                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license
# 0                          0                 NaN
# 1                         30  IT058091C29VJSIZQZ
# 2                         13  it058091c2kv6epw8f
# 3                         21  IT058091C20YD35BX2
# 4                          0  IT058091C20YD35BX2
# ...                      ...                 ...
# 37647                      0  IT058091B4XPH449TB
# 37648                      0  IT058091C2RGTLCJNR
# 37649                      0  IT058091C2DZHIDY6A
# 37650                      0  it058091c2rf3ps25z
# 37651                      0  IT058091C26JO2EDQQ
#
# [37652 rows x 18 columns]

# %%
df_neighbourhoods = pd.read_csv("neighbourhoods.csv")
df_neighbourhoods["neighbourhood"].values
# Out:
# array(['I Centro Storico', 'III Monte Sacro', 'II Parioli/Nomentano',
#        'IV Tiburtina', 'IX Eur', 'VIII Appia Antica',
#        'VII San Giovanni/Cinecittà', 'VI Roma delle Torri',
#        'V Prenestino/Centocelle', 'XI Arvalia/Portuense', 'XIII Aurelia',
#        'XII Monte Verde', 'XIV Monte Mario', 'X Ostia/Acilia',
#        'XV Cassia/Flaminia'], dtype=object)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Check how many NaN values

# %%
df_listings.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             8
# neighbourhood_group               37652
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              4088
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        5397
# reviews_per_month                  5397
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            3063
# dtype: int64

# %%
# Check all host_names with NaN Values
df_listings[df_listings["host_name"].isna()]
# Out:
#                         id                                               name  \
# 3017               8834149                    Irene's home. Bright apartament
# 10849             45646453  R 1145 Amatos Apartment With Break Fast, Mini-...
# 10850             45646761  R 1146 Bosco’s Family Room With Break Fast, Te...
# 10956             45761969  R 1164 Dante’s Suite Duplex With Central Heati...
# 11229             47793082  R 1166 Hotel Alba - Double/Twin Classic Room w...
# 11230             47793087  R 1168 Hotel Violetta (Double or Twin Room) wi...
# 31734  1352051912970160214                   Easy Host Apt Almapetra Colosseo
# 32060  1360024890693130906                       Easy Host Apt Almapetra Fori
#
#          host_id host_name  neighbourhood_group        neighbourhood  \
# 3017    46268435       NaN                  NaN  VI Roma delle Torri
# 10849  194247046       NaN                  NaN     I Centro Storico
# 10850  194247046       NaN                  NaN     I Centro Storico
# 10956  194247046       NaN                  NaN     I Centro Storico
# 11229  194247046       NaN                  NaN     I Centro Storico
# 11230  194247046       NaN                  NaN     I Centro Storico
# 31734  677103700       NaN                  NaN     I Centro Storico
# 32060  677103700       NaN                  NaN     I Centro Storico
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 3017   41.866350  12.584190  Entire home/apt  126.0              31
# 10849  41.920650  12.457030  Entire home/apt  150.0              31
# 10850  41.918940  12.457270  Entire home/apt  306.0              31
# 10956  41.899120  12.470350  Entire home/apt  356.0              31
# 11229  41.902120  12.488620     Private room  138.0              31
# 11230  41.904890  12.484550     Private room  150.0              31
# 31734  41.891277  12.500056  Entire home/apt  208.0               2
# 32060  41.891337  12.482719  Entire home/apt  250.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 3017                   6  2021-07-29               0.05
# 10849                  0         NaN                NaN
# 10850                  0         NaN                NaN
# 10956                  0         NaN                NaN
# 11229                  0         NaN                NaN
# 11230                  0         NaN                NaN
# 31734                  0         NaN                NaN
# 32060                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 3017                                1               362
# 10849                               5               364
# 10850                               5               364
# 10956                               5               364
# 11229                               5               364
# 11230                               5               364
# 31734                               2               218
# 32060                               2               205
#
#        number_of_reviews_ltm             license
# 3017                       0                 NaN
# 10849                      0                 NaN
# 10850                      0                 NaN
# 10956                      0                 NaN
# 11229                      0                 NaN
# 11230                      0                 NaN
# 31734                      0  IT058091B486FIY7EL
# 32060                      0  IT058091C2HIE8HXQ3

# %%
# Check if there are associated host_name values for its host_id
id_NaN = df_listings[df_listings["host_name"].isna()]["host_id"].values
id_NaN = list(dict.fromkeys(id_NaN))
id_NaN
# Out:
# [46268435, 194247046, 677103700]

# %%
df_listings[df_listings["host_id"].isin(id_NaN)]
# Out:
#                         id                                               name  \
# 3017               8834149                    Irene's home. Bright apartament
# 10849             45646453  R 1145 Amatos Apartment With Break Fast, Mini-...
# 10850             45646761  R 1146 Bosco’s Family Room With Break Fast, Te...
# 10956             45761969  R 1164 Dante’s Suite Duplex With Central Heati...
# 11229             47793082  R 1166 Hotel Alba - Double/Twin Classic Room w...
# 11230             47793087  R 1168 Hotel Violetta (Double or Twin Room) wi...
# 31734  1352051912970160214                   Easy Host Apt Almapetra Colosseo
# 32060  1360024890693130906                       Easy Host Apt Almapetra Fori
#
#          host_id host_name  neighbourhood_group        neighbourhood  \
# 3017    46268435       NaN                  NaN  VI Roma delle Torri
# 10849  194247046       NaN                  NaN     I Centro Storico
# 10850  194247046       NaN                  NaN     I Centro Storico
# 10956  194247046       NaN                  NaN     I Centro Storico
# 11229  194247046       NaN                  NaN     I Centro Storico
# 11230  194247046       NaN                  NaN     I Centro Storico
# 31734  677103700       NaN                  NaN     I Centro Storico
# 32060  677103700       NaN                  NaN     I Centro Storico
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 3017   41.866350  12.584190  Entire home/apt  126.0              31
# 10849  41.920650  12.457030  Entire home/apt  150.0              31
# 10850  41.918940  12.457270  Entire home/apt  306.0              31
# 10956  41.899120  12.470350  Entire home/apt  356.0              31
# 11229  41.902120  12.488620     Private room  138.0              31
# 11230  41.904890  12.484550     Private room  150.0              31
# 31734  41.891277  12.500056  Entire home/apt  208.0               2
# 32060  41.891337  12.482719  Entire home/apt  250.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 3017                   6  2021-07-29               0.05
# 10849                  0         NaN                NaN
# 10850                  0         NaN                NaN
# 10956                  0         NaN                NaN
# 11229                  0         NaN                NaN
# 11230                  0         NaN                NaN
# 31734                  0         NaN                NaN
# 32060                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 3017                                1               362
# 10849                               5               364
# 10850                               5               364
# 10956                               5               364
# 11229                               5               364
# 11230                               5               364
# 31734                               2               218
# 32060                               2               205
#
#        number_of_reviews_ltm             license
# 3017                       0                 NaN
# 10849                      0                 NaN
# 10850                      0                 NaN
# 10956                      0                 NaN
# 11229                      0                 NaN
# 11230                      0                 NaN
# 31734                      0  IT058091B486FIY7EL
# 32060                      0  IT058091C2HIE8HXQ3

# %% [markdown]
# As seen in the results, the host_name are all NaN for all NaN values in host_id

# %%
# Rename theme for temporary. # Since it is only 3, we add 3 temporary host names
new_host_names = [f'Temp Host {i+1}' for i in range(len(id_NaN))]

id_to_name_map = dict(zip(id_NaN, new_host_names,))

id_to_name_map
# Out:
# {46268435: 'Temp Host 1', 194247046: 'Temp Host 2', 677103700: 'Temp Host 3'}

# %%
# use fillna() with .map() of host_id
df_listings["host_name"] = df_listings["host_name"].fillna(df_listings["host_id"].map(id_to_name_map))

# %%
df_listings[df_listings["host_id"].isin(id_NaN)]
# Out:
#                         id                                               name  \
# 3017               8834149                    Irene's home. Bright apartament
# 10849             45646453  R 1145 Amatos Apartment With Break Fast, Mini-...
# 10850             45646761  R 1146 Bosco’s Family Room With Break Fast, Te...
# 10956             45761969  R 1164 Dante’s Suite Duplex With Central Heati...
# 11229             47793082  R 1166 Hotel Alba - Double/Twin Classic Room w...
# 11230             47793087  R 1168 Hotel Violetta (Double or Twin Room) wi...
# 31734  1352051912970160214                   Easy Host Apt Almapetra Colosseo
# 32060  1360024890693130906                       Easy Host Apt Almapetra Fori
#
#          host_id    host_name  neighbourhood_group        neighbourhood  \
# 3017    46268435  Temp Host 1                  NaN  VI Roma delle Torri
# 10849  194247046  Temp Host 2                  NaN     I Centro Storico
# 10850  194247046  Temp Host 2                  NaN     I Centro Storico
# 10956  194247046  Temp Host 2                  NaN     I Centro Storico
# 11229  194247046  Temp Host 2                  NaN     I Centro Storico
# 11230  194247046  Temp Host 2                  NaN     I Centro Storico
# 31734  677103700  Temp Host 3                  NaN     I Centro Storico
# 32060  677103700  Temp Host 3                  NaN     I Centro Storico
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 3017   41.866350  12.584190  Entire home/apt  126.0              31
# 10849  41.920650  12.457030  Entire home/apt  150.0              31
# 10850  41.918940  12.457270  Entire home/apt  306.0              31
# 10956  41.899120  12.470350  Entire home/apt  356.0              31
# 11229  41.902120  12.488620     Private room  138.0              31
# 11230  41.904890  12.484550     Private room  150.0              31
# 31734  41.891277  12.500056  Entire home/apt  208.0               2
# 32060  41.891337  12.482719  Entire home/apt  250.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 3017                   6  2021-07-29               0.05
# 10849                  0         NaN                NaN
# 10850                  0         NaN                NaN
# 10956                  0         NaN                NaN
# 11229                  0         NaN                NaN
# 11230                  0         NaN                NaN
# 31734                  0         NaN                NaN
# 32060                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 3017                                1               362
# 10849                               5               364
# 10850                               5               364
# 10956                               5               364
# 11229                               5               364
# 11230                               5               364
# 31734                               2               218
# 32060                               2               205
#
#        number_of_reviews_ltm             license
# 3017                       0                 NaN
# 10849                      0                 NaN
# 10850                      0                 NaN
# 10956                      0                 NaN
# 11229                      0                 NaN
# 11230                      0                 NaN
# 31734                      0  IT058091B486FIY7EL
# 32060                      0  IT058091C2HIE8HXQ3

# %%
# TO DO: Investigate why more than 10% of data have NaN price

# %%
df_listings[df_listings["price"].isna()]["availability_365"].value_counts()
# Out:
# availability_365
# 0      2094
# 364      85
# 1        53
# 365      34
# 269      34
#        ...
# 201       1
# 184       1
# 130       1
# 200       1
# 25        1
# Name: count, Length: 358, dtype: int64

# %%
# TO DO: Clean last_reviews column [DONE] - ANSWER : DO NOT DROP SINCE IT IS NEEDED
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN                NaN
# 37648                  0         NaN                NaN
# 37649                  0         NaN                NaN
# 37650                  0         NaN                NaN
# 37651                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license
# 0                          0                 NaN
# 1                         30  IT058091C29VJSIZQZ
# 2                         13  it058091c2kv6epw8f
# 3                         21  IT058091C20YD35BX2
# 4                          0  IT058091C20YD35BX2
# ...                      ...                 ...
# 37647                      0  IT058091B4XPH449TB
# 37648                      0  IT058091C2RGTLCJNR
# 37649                      0  IT058091C2DZHIDY6A
# 37650                      0  it058091c2rf3ps25z
# 37651                      0  IT058091C26JO2EDQQ
#
# [37652 rows x 18 columns]

# %%
# last_reviews and reviews per month are NaN because there are no reviews for the listing. 
# Leave last_reviews as NaN, and last_reviews as 0

# %%
df_listings["reviews_per_month"] = df_listings["reviews_per_month"].fillna(0)

# %%
# final cout
df_listings.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               37652
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              4088
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        5397
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            3063
# dtype: int64

# %%
df_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df_listings["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    28294
# Private room        8887
# Hotel room           370
# Shared room          101
# Name: count, dtype: int64

# %%
# Check price value

# %%
min_price_listing = df_listings["price"].min()
max_price_listing = df_listings["price"].max()

print(f"{min_price_listing} - {max_price_listing}")
# Out:
# 8.0 - 10515.0

# %%
df_listings["price"].mean()
# Out:
# 197.32800023835063

# %%
df_listings["price"].describe().round(2)
# Out:
# count    33564.00
# mean       197.33
# std        443.19
# min          8.00
# 25%         93.00
# 50%        133.00
# 75%        195.25
# max      10515.00
# Name: price, dtype: float64

# %%
df_listings["minimum_nights"].value_counts()
# Out:
# minimum_nights
# 1      13952
# 2      13052
# 3       5608
# 31      3606
# 4        709
# 5        268
# 7        106
# 6         65
# 90        27
# 30        27
# 365       25
# 32        23
# 10        23
# 15        19
# 60        17
# 20        15
# 28        11
# 14        10
# 360        8
# 180        8
# 100        6
# 170        5
# 120        5
# 45         4
# 29         4
# 35         4
# 21         3
# 40         3
# 8          3
# 364        3
# 150        3
# 25         2
# 50         2
# 730        2
# 56         2
# 110        1
# 24         1
# 12         1
# 41         1
# 11         1
# 63         1
# 27         1
# 311        1
# 350        1
# 70         1
# 105        1
# 26         1
# 99         1
# 200        1
# 55         1
# 300        1
# 58         1
# 179        1
# 186        1
# 720        1
# 80         1
# 280        1
# Name: count, dtype: int64

# %%
df_listings = df_listings[df_listings["availability_365"] != 0]
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN               0.00
# 37648                  0         NaN               0.00
# 37649                  0         NaN               0.00
# 37650                  0         NaN               0.00
# 37651                  0         NaN               0.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license
# 0                          0                 NaN
# 1                         30  IT058091C29VJSIZQZ
# 2                         13  it058091c2kv6epw8f
# 3                         21  IT058091C20YD35BX2
# 4                          0  IT058091C20YD35BX2
# ...                      ...                 ...
# 37647                      0  IT058091B4XPH449TB
# 37648                      0  IT058091C2RGTLCJNR
# 37649                      0  IT058091C2DZHIDY6A
# 37650                      0  it058091c2rf3ps25z
# 37651                      0  IT058091C26JO2EDQQ
#
# [35238 rows x 18 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# TO DO: Create a new column indicating if it is short rental or not
# For this we say if minimum_nights < 31

df_listings["is_short_term"] = df_listings["minimum_nights"] <= 31
# Out:
# /tmp/ipykernel_2410/996813911.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listings["is_short_term"] = df_listings["minimum_nights"] <= 31

# %%
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN               0.00
# 37648                  0         NaN               0.00
# 37649                  0         NaN               0.00
# 37650                  0         NaN               0.00
# 37651                  0         NaN               0.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license  is_short_term
# 0                          0                 NaN           True
# 1                         30  IT058091C29VJSIZQZ           True
# 2                         13  it058091c2kv6epw8f           True
# 3                         21  IT058091C20YD35BX2           True
# 4                          0  IT058091C20YD35BX2           True
# ...                      ...                 ...            ...
# 37647                      0  IT058091B4XPH449TB           True
# 37648                      0  IT058091C2RGTLCJNR           True
# 37649                      0  IT058091C2DZHIDY6A           True
# 37650                      0  it058091c2rf3ps25z           True
# 37651                      0  IT058091C26JO2EDQQ           True
#
# [35238 rows x 19 columns]

# %%
# You can filter out for rentals that are short term (minimum number of nights is 1 month)
df_listings[df_listings["is_short_term"] == False]
# Out:
#                         id                                              name  \
# 73                  282929                 Bright & cozy double room in Rome
# 96                   53203  Sanniti apartment, San Lorenzo stylish top floor
# 237                 588080                  ENCHANTING ROMAN VILLA WITH POOL
# 241                 158761                 DELIGHTFUL & COZY FLAT Trastevere
# 316                 426237                Blue double room with private bath
# ...                    ...                                               ...
# 36502  1465087642416993184        Stanza condivisa - Posto letto (Portuense)
# 36505  1465094446743516993             Stanza doppia uso singola (Portuense)
# 36506  1465097027869511375              Stanza con bagno privato (Portuense)
# 37277  1495484953051801925                      HospitalityrRome San Lorenzo
# 37291  1496230428993519362                            Piazza Vittorio Bright
#
#          host_id          host_name  neighbourhood_group  \
# 73       1474010  Rosanna E Daniele                  NaN
# 96        247495           Gabriele                  NaN
# 237      1528063             Chiara                  NaN
# 241       761827            Dorotea                  NaN
# 316      1775004              Irina                  NaN
# ...          ...                ...                  ...
# 36502  707059803          Gianluigi                  NaN
# 36505  707059803          Gianluigi                  NaN
# 36506  707059803          Gianluigi                  NaN
# 37277  654762984            Massimo                  NaN
# 37291  691481754     Maria Cristina                  NaN
#
#                     neighbourhood   latitude  longitude        room_type  \
# 73     VII San Giovanni/Cinecittà  41.857840  12.557640     Private room
# 96           II Parioli/Nomentano  41.898050  12.515630  Entire home/apt
# 237            XV Cassia/Flaminia  41.976860  12.428090  Entire home/apt
# 241              I Centro Storico  41.886030  12.468280  Entire home/apt
# 316          II Parioli/Nomentano  41.913880  12.503050     Private room
# ...                           ...        ...        ...              ...
# 36502        XI Arvalia/Portuense  41.862410  12.459120      Shared room
# 36505        XI Arvalia/Portuense  41.862200  12.459230     Private room
# 36506        XI Arvalia/Portuense  41.862110  12.459520     Private room
# 37277        II Parioli/Nomentano  41.896180  12.513222  Entire home/apt
# 37291            I Centro Storico  41.895706  12.503453  Entire home/apt
#
#        price  minimum_nights  number_of_reviews last_review  \
# 73      26.0             350                 12  2015-08-08
# 96     108.0              90                101  2024-09-02
# 237    168.0              60                 17  2016-08-23
# 241     90.0             360                  8  2017-04-19
# 316     89.0              32                127  2024-10-21
# ...      ...             ...                ...         ...
# 36502   20.0              90                  0         NaN
# 36505   28.0              90                  0         NaN
# 36506   32.0              90                  0         NaN
# 37277   75.0              60                  0         NaN
# 37291  103.0              40                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 73                  0.07                               1               257
# 96                  0.56                               1                46
# 237                 0.11                               1               304
# 241                 0.06                              18               363
# 316                 0.84                               2               350
# ...                  ...                             ...               ...
# 36502               0.00                               4               259
# 36505               0.00                               4               227
# 36506               0.00                               4               318
# 37277               0.00                               2               254
# 37291               0.00                               2               282
#
#        number_of_reviews_ltm             license  is_short_term
# 73                         0                 NaN          False
# 96                         0  IT058091C2IBQXC78S          False
# 237                        0                 NaN          False
# 241                        0                 NaN          False
# 316                        3                 NaN          False
# ...                      ...                 ...            ...
# 36502                      0                 NaN          False
# 36505                      0                 NaN          False
# 36506                      0                 NaN          False
# 37277                      0  IT058091C2EDTB459N          False
# 37291                      0                 NaN          False
#
# [129 rows x 19 columns]

# %%
df_listings["renter_type"] = ["business" if x > 1 else "casual" for x in df_listings['calculated_host_listings_count']]
# Out:
# /tmp/ipykernel_2410/4103492854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listings["renter_type"] = ["business" if x > 1 else "casual" for x in df_listings['calculated_host_listings_count']]

# %%
df_listings[["id", "name", "host_id", "host_name","renter_type"]]
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name renter_type
# 0           3047      Elif    business
# 1          44552    Serena      casual
# 2          11756       Gea      casual
# 3          75450   Sabrina    business
# 4          75450   Sabrina    business
# ...          ...       ...         ...
# 37647  554023719     Lucky    business
# 37648  718755020     David      casual
# 37649    9403439    Andrea    business
# 37650  579802615  Domenico    business
# 37651  357232108    Miriam    business
#
# [35238 rows x 5 columns]

# %%
# You can get number of individual hosts
# You can get number of hosts who has multiple listings
# You can get number of hosts who dont have a license depending if they are casual or not
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN               0.00
# 37648                  0         NaN               0.00
# 37649                  0         NaN               0.00
# 37650                  0         NaN               0.00
# 37651                  0         NaN               0.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license  is_short_term renter_type
# 0                          0                 NaN           True    business
# 1                         30  IT058091C29VJSIZQZ           True      casual
# 2                         13  it058091c2kv6epw8f           True      casual
# 3                         21  IT058091C20YD35BX2           True    business
# 4                          0  IT058091C20YD35BX2           True    business
# ...                      ...                 ...            ...         ...
# 37647                      0  IT058091B4XPH449TB           True    business
# 37648                      0  IT058091C2RGTLCJNR           True      casual
# 37649                      0  IT058091C2DZHIDY6A           True    business
# 37650                      0  it058091c2rf3ps25z           True    business
# 37651                      0  IT058091C26JO2EDQQ           True    business
#
# [35238 rows x 20 columns]

# %%
# Drop neighbourhood_group as neighbourhood column already serves that purpose, and neighbourhood is already the highest group that could be done in Rome
# df_listings = df_listings.drop(['neighbourhood_group'], axis=1)

# %%
# final count
df_listings.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               35238
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1994
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        4686
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            1905
# is_short_term                         0
# renter_type                           0
# dtype: int64

# %%
df_listings.to_csv('rome_airbnb_clean.csv', index=False)

# %%
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN               0.00
# 37648                  0         NaN               0.00
# 37649                  0         NaN               0.00
# 37650                  0         NaN               0.00
# 37651                  0         NaN               0.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license  is_short_term renter_type
# 0                          0                 NaN           True    business
# 1                         30  IT058091C29VJSIZQZ           True      casual
# 2                         13  it058091c2kv6epw8f           True      casual
# 3                         21  IT058091C20YD35BX2           True    business
# 4                          0  IT058091C20YD35BX2           True    business
# ...                      ...                 ...            ...         ...
# 37647                      0  IT058091B4XPH449TB           True    business
# 37648                      0  IT058091C2RGTLCJNR           True      casual
# 37649                      0  IT058091C2DZHIDY6A           True    business
# 37650                      0  it058091c2rf3ps25z           True    business
# 37651                      0  IT058091C26JO2EDQQ           True    business
#
# [35238 rows x 20 columns]

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Main Research Question 1

# %% [markdown]
# #### 1. What are the pricing and popularity hotspots in Rome

# %%
# Import libraries
import os
import pyproj
import matplotlib.pyplot as plt

# %%
# Fixing issue in personal laptop where geopandas library can't be loaded. (Must be done everytime)

# Ask pyproj where the data directory is
path_to_proj_data = pyproj.datadir.get_data_dir()

# Force the environment variable to use this path
os.environ['PROJ_LIB'] = path_to_proj_data

# Now import geopandas
import geopandas as gpd

print(f"PROJ data found at: {path_to_proj_data}")

# Load your file
df_geo_rome = gpd.read_file("neighbourhoods.geojson")
# Out:
# PROJ data found at: /home/matthew/.workspaces/miniconda3/envs/ds-env/share/proj

# %%
# Turn CSV into GeoDF
df_geo_listings = gpd.GeoDataFrame(df_listings,
                                   geometry=gpd.points_from_xy(df_listings["longitude"], df_listings["latitude"]),
                                   crs="EPSG:4326"
                                  )

# %%
# Ensure both map layers use the same projection (Required!)
df_geo_listings = df_geo_listings.to_crs(df_geo_rome.crs)

joined = gpd.sjoin(df_geo_listings, df_geo_rome, how="inner", predicate="within")

# Count the points per neighbourhood
counts = joined.groupby(by="neighbourhood_right").size().reset_index(name='point_count')

# Merge the counts back into the original neighbourhood map
final_map_count_hotspot = df_geo_rome.merge(counts, left_on="neighbourhood", right_on="neighbourhood_right", how='left')

# Fill NaN values with 0 (for neighbourhoods with no points)
final_map_count_hotspot['point_count'] = final_map_count_hotspot['point_count'].fillna(0)

# %%
final_map_count_hotspot.sort_values(by="point_count", ascending=False)[["neighbourhood", "point_count"]]
# Out:
#                  neighbourhood  point_count
# 0             I Centro Storico        17507
# 4   VII San Giovanni/Cinecittà         3044
# 10                XIII Aurelia         2534
# 14        II Parioli/Nomentano         2359
# 9              XII Monte Verde         1877
# 13     V Prenestino/Centocelle         1759
# 5            VIII Appia Antica         1125
# 7               X Ostia/Acilia          987
# 11             XIV Monte Mario          801
# 8         XI Arvalia/Portuense          733
# 2                 IV Tiburtina          627
# 1              III Monte Sacro          611
# 12          XV Cassia/Flaminia          561
# 6                       IX Eur          397
# 3          VI Roma delle Torri          316

# %%
# Note this only answers chloroplot map of how many dots are per neighbourhood

fig, ax = plt.subplots(1, 1, figsize=(12, 10))

upper_limit = final_map_count_hotspot['point_count'].quantile(0.95)

final_map_count_hotspot.plot(column='point_count',
                             ax=ax,
                             legend=True,
                             legend_kwds={'label': "Number of Listings"},
                             cmap='RdBu_r',
                             vmax=upper_limit)

# Add Labels
for idx, row in final_map_count_hotspot.iterrows():
    xy = row['geometry'].representative_point().coords[0]
    
    ax.annotate(text=row['neighbourhood'].split(' ')[0], 
                xy=xy, 
                horizontalalignment='center', 
                fontsize=10, 
                color='white'
               )

ax.set_title('Rome Airbnb Number of Listings Hotspots')
ax.set_axis_off()
plt.savefig('1-1.png')
plt.show()

# %%
# Scaling Factor: If you have 10,000 listings, drawing 10,000 dots might be slow/messy.
listings_per_dot = 2
to_keep = 1 / listings_per_dot

sampled_df = df_geo_listings.sample(frac=to_keep, random_state=42)

# sampled_df["median_price"] = sampled_df.groupby(by="neighbourhood").median()
median_prices = sampled_df.groupby(by="neighbourhood")["price"].median()
median_prices = median_prices.reset_index()

median_prices
# Out:
#                  neighbourhood  price
# 0             I Centro Storico  172.5
# 1         II Parioli/Nomentano  119.5
# 2              III Monte Sacro   89.0
# 3                 IV Tiburtina   86.5
# 4                       IX Eur  102.0
# 5      V Prenestino/Centocelle   80.0
# 6          VI Roma delle Torri   76.0
# 7   VII San Giovanni/Cinecittà  105.0
# 8            VIII Appia Antica  100.0
# 9               X Ostia/Acilia   90.0
# 10        XI Arvalia/Portuense   90.0
# 11             XII Monte Verde  108.0
# 12                XIII Aurelia  123.0
# 13             XIV Monte Mario   98.0
# 14          XV Cassia/Flaminia   93.0

# %%
sampled_df = sampled_df.merge(median_prices, on="neighbourhood", how="left")
sampled_df
# Out:
#                         id                                               name  \
# 0      1402614759943139637                         Casa "FlAVIA" room in home
# 1      1113708824153998791  Quartiere Trieste Metro Annibaliano-Wifi, Smar...
# 2                 42656911  Large familiar suite with bathroom & wifi in Rome
# 3                 34014520    Best Night in Trastevere Movida in Via del Moro
# 4      1507304914571794242      Trastevere Sweet Nook nel cuore di Trastevere
# ...                    ...                                                ...
# 17614  1260237935711500888                                  a casa di Manuela
# 17615   733845463635959556      Casa Gelsomino | St. Peter Boutique Apartment
# 17616             20648439               Amazing Piazza Venezia Suite Int. 10
# 17617  1364340803076165747            Trastevere Essence by Nosdom Properties
# 17618  1032373327608615661                                      Stanza Gialla
#
#          host_id       host_name  neighbourhood_group  \
# 0       33995489          Simone                  NaN
# 1       24653680         Giorgio                  NaN
# 2      146306167         Tatiana                  NaN
# 3      256828452  Pier Francesco                  NaN
# 4      594901294         Lorenzo                  NaN
# ...          ...             ...                  ...
# 17614  655432201         Manuela                  NaN
# 17615    7282075           Dario                  NaN
# 17616   20428282       Nicoletta                  NaN
# 17617  494094936           Paolo                  NaN
# 17618  226169245        Leonardo                  NaN
#
#                     neighbourhood   latitude  longitude        room_type  \
# 0      VII San Giovanni/Cinecittà  41.877694  12.516039     Private room
# 1            II Parioli/Nomentano  41.925420  12.515598  Entire home/apt
# 2                I Centro Storico  41.906080  12.501770     Private room
# 3                I Centro Storico  41.890100  12.470930     Private room
# 4                I Centro Storico  41.890130  12.466800  Entire home/apt
# ...                           ...        ...        ...              ...
# 17614        II Parioli/Nomentano  41.913830  12.502900  Entire home/apt
# 17615                XIII Aurelia  41.899727  12.452131  Entire home/apt
# 17616            I Centro Storico  41.897053  12.482077  Entire home/apt
# 17617            I Centro Storico  41.888466  12.470889  Entire home/apt
# 17618          XV Cassia/Flaminia  41.951596  12.474940     Private room
#
#        price_x  ...  last_review  reviews_per_month  \
# 0         28.0  ...          NaN               0.00
# 1         67.0  ...   2025-09-01               3.36
# 2          NaN  ...   2023-06-21               0.58
# 3         84.0  ...   2025-09-01               1.71
# 4        147.0  ...          NaN               0.00
# ...        ...  ...          ...                ...
# 17614    185.0  ...   2025-08-03               1.00
# 17615    214.0  ...   2025-05-13               0.59
# 17616    407.0  ...   2024-11-02               0.06
# 17617    299.0  ...   2025-09-10               3.77
# 17618     96.0  ...   2024-09-20               0.12
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                                  6               300                      0
# 1                                  2               337                     35
# 2                                  5               364                      0
# 3                                  3               241                     38
# 4                                  1               365                      0
# ...                              ...               ...                    ...
# 17614                              1               286                     11
# 17615                              2               308                      1
# 17616                             71               246                      1
# 17617                              9               291                     21
# 17618                             19               363                      1
#
#                   license  is_short_term renter_type  \
# 0                     NaN           True    business
# 1      IT058091C2OVS3SZP3           True    business
# 2                     NaN           True    business
# 3      IT058091B4B7W8CXKR           True    business
# 4      IT058091C2CFRYJGW5           True      casual
# ...                   ...            ...         ...
# 17614  IT058091C2ZL8EQ6NV           True      casual
# 17615  IT058091C2HOGM2XAT           True    business
# 17616  IT058091B42U539HOO           True    business
# 17617  IT058091C2CYMGQ9GI           True    business
# 17618  IT058091B4Y3SNOR5I           True    business
#
#                         geometry price_y
# 0      POINT (12.51604 41.87769)   105.0
# 1       POINT (12.5156 41.92542)   119.5
# 2      POINT (12.50177 41.90608)   172.5
# 3       POINT (12.47093 41.8901)   172.5
# 4       POINT (12.4668 41.89013)   172.5
# ...                          ...     ...
# 17614   POINT (12.5029 41.91383)   119.5
# 17615  POINT (12.45213 41.89973)   123.0
# 17616  POINT (12.48208 41.89705)   172.5
# 17617  POINT (12.47089 41.88847)   172.5
# 17618   POINT (12.47494 41.9516)    93.0
#
# [17619 rows x 22 columns]

# %%
# --- PLOTTING ---
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

final_map_count_hotspot.plot(ax=ax, color='#F5F5F5', edgecolor='#D3D3D3')

upper_limit = sampled_df["price_y"].quantile(0.90)

scatter_density_price = ax.scatter(
    x=sampled_df["longitude"],
    y=sampled_df["latitude"],
    s=2,
    c=sampled_df["price_y"],
    cmap='viridis',
    alpha=0.9,
    linewidth=0,
    vmax=upper_limit
)

cbar = plt.colorbar(scatter_density_price, ax=ax, shrink=0.7) 

# Add Color Legend
cbar.set_label('Neighborhood Median Price (€)', fontsize=12, labelpad=10)

# Add Labels
for idx, row in final_map_count_hotspot.iterrows():
    xy = row['geometry'].representative_point().coords[0]
    
    ax.annotate(
        text=row['neighbourhood'].split(' ')[0], 
        xy=xy, 
        horizontalalignment='center', 
        fontsize=10, 
        color='black',
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="none", alpha=0.7)
        )
        

ax.set_title(f'Rome Airbnb Listings Distribution (1 Dot = {listings_per_dot} Listings)', fontsize=12)
ax.set_axis_off()
plt.savefig('1-1_dot_density.png', dpi=300) 
plt.show()

# %%
neighbourhood_stats = joined.groupby('neighbourhood_right')[['price', 'number_of_reviews_ltm']].median().reset_index()
neighbourhood_stats.rename(columns={
    'neighbourhood_right':'neighbourhood',
    'price': 'median_price', 
    'number_of_reviews_ltm': 'median_reviews'
}, inplace=True)

# %%
final_map_pricing_hotspot = df_geo_rome.merge(neighbourhood_stats, left_on="neighbourhood", right_on="neighbourhood", how='left')

# %%
final_map_pricing_hotspot.sort_values(by="median_price", ascending=False)[["neighbourhood", "median_price"]]
# Out:
#                  neighbourhood  median_price
# 0             I Centro Storico         173.0
# 10                XIII Aurelia         122.0
# 14        II Parioli/Nomentano         119.0
# 9              XII Monte Verde         108.0
# 4   VII San Giovanni/Cinecittà         104.0
# 5            VIII Appia Antica         102.0
# 11             XIV Monte Mario          97.0
# 12          XV Cassia/Flaminia          96.0
# 6                       IX Eur          92.0
# 1              III Monte Sacro          90.0
# 7               X Ostia/Acilia          90.0
# 2                 IV Tiburtina          89.0
# 8         XI Arvalia/Portuense          87.0
# 13     V Prenestino/Centocelle          80.0
# 3          VI Roma delle Torri          74.0

# %%
upper_limit = final_map_pricing_hotspot['median_price'].quantile(0.95)

fig, ax = plt.subplots(1, 1, figsize=(12, 10))
final_map_pricing_hotspot.plot(
    column='median_price', 
    ax=ax, 
    legend=True,
    legend_kwds={'label': "Median Price (€)"},
    cmap='RdBu_r',
    vmin=50,
    vmax=upper_limit
)

# Add Labels
for idx, row in final_map_count_hotspot.iterrows():
    xy = row['geometry'].representative_point().coords[0]
    
    ax.annotate(text=row['neighbourhood'].split(' ')[0], 
                xy=xy, 
                horizontalalignment='center', 
                fontsize=10, 
                color='black'
               )

ax.set_title('Rome Airbnb Price Hotspots (Median Price per Neighbourhood)')
ax.set_axis_off()
plt.savefig("1-2.png")
plt.show()

# %%
final_map = df_geo_rome.merge(neighbourhood_stats, left_on="neighbourhood", right_on="neighbourhood", how='left')

upper_limit = final_map['median_reviews'].quantile(0.95)

fig, ax = plt.subplots(1, 1, figsize=(12, 10))
final_map.plot(
    column='median_price', 
    ax=ax, 
    legend=True,
    legend_kwds={'label': "Median Reviews"},
    cmap='RdBu_r',       # 'viridis', 'plasma', or 'coolwarm' are good for prices
)

ax.set_title('Rome Airbnb Popularity Hotspot (Median Reviews per Neighbourhood)')
ax.set_axis_off() # Hide axis numbers
plt.savefig("1-3.png")
plt.show()

# %% [markdown]
# ## 2. What is the dominant type of listing in each neighbourhood, and who is offering it?

# %%
df_listings
# Out:
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name  neighbourhood_group            neighbourhood  \
# 0           3047      Elif                  NaN        VIII Appia Antica
# 1          44552    Serena                  NaN         I Centro Storico
# 2          11756       Gea                  NaN     II Parioli/Nomentano
# 3          75450   Sabrina                  NaN         I Centro Storico
# 4          75450   Sabrina                  NaN         I Centro Storico
# ...          ...       ...                  ...                      ...
# 37647  554023719     Lucky                  NaN         I Centro Storico
# 37648  718755020     David                  NaN         I Centro Storico
# 37649    9403439    Andrea                  NaN  V Prenestino/Centocelle
# 37650  579802615  Domenico                  NaN         I Centro Storico
# 37651  357232108    Miriam                  NaN          XIV Monte Mario
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      41.871360  12.482150     Private room   57.0              31
# 1      41.895447  12.491181  Entire home/apt  110.0               2
# 2      41.925820  12.469280  Entire home/apt  124.0               3
# 3      41.908230  12.452930  Entire home/apt  162.0               3
# 4      41.908283  12.452617  Entire home/apt  150.0               3
# ...          ...        ...              ...    ...             ...
# 37647  41.893540  12.505190  Entire home/apt  151.0               1
# 37648  41.902630  12.491156  Entire home/apt  147.0               1
# 37649  41.865398  12.547593  Entire home/apt  225.0               1
# 37650  41.893728  12.507961     Private room   72.0               2
# 37651  41.927240  12.442380     Private room   77.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      5  2015-05-08               0.04
# 1                    284  2025-07-05               1.62
# 2                     85  2025-08-01               0.47
# 3                    178  2025-08-05               1.07
# 4                     46  2024-07-19               0.32
# ...                  ...         ...                ...
# 37647                  0         NaN               0.00
# 37648                  0         NaN               0.00
# 37649                  0         NaN               0.00
# 37650                  0         NaN               0.00
# 37651                  0         NaN               0.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   6               365
# 1                                   1               295
# 2                                   1               162
# 3                                   3               187
# 4                                   3               168
# ...                               ...               ...
# 37647                               4               192
# 37648                               1               343
# 37649                               8                28
# 37650                               2               353
# 37651                               5               236
#
#        number_of_reviews_ltm             license  is_short_term renter_type
# 0                          0                 NaN           True    business
# 1                         30  IT058091C29VJSIZQZ           True      casual
# 2                         13  it058091c2kv6epw8f           True      casual
# 3                         21  IT058091C20YD35BX2           True    business
# 4                          0  IT058091C20YD35BX2           True    business
# ...                      ...                 ...            ...         ...
# 37647                      0  IT058091B4XPH449TB           True    business
# 37648                      0  IT058091C2RGTLCJNR           True      casual
# 37649                      0  IT058091C2DZHIDY6A           True    business
# 37650                      0  it058091c2rf3ps25z           True    business
# 37651                      0  IT058091C26JO2EDQQ           True    business
#
# [35238 rows x 20 columns]

# %%
df_listings_type = pd.crosstab(df_listings['neighbourhood'], df_listings['room_type'], normalize='index')
df_listings_type *= 100

# get roman numerals only for neighbourhoods
df_listings_type.index = [name.split(' ')[0] for name in df_listings_type.index]

df_listings_type
# Out:
# room_type  Entire home/apt  Hotel room  Private room  Shared room
# I                75.673978    1.228010     22.869545     0.228467
# II               76.430691    0.508690     22.933446     0.127173
# III              77.741408    0.490998     21.767594     0.000000
# IV               66.985646    0.000000     32.854864     0.159490
# IX               79.093199    0.251889     20.654912     0.000000
# V                77.146106    0.000000     21.489483     1.364412
# VI               71.202532    0.000000     26.582278     2.215190
# VII              74.967148    0.591327     24.408673     0.032852
# VIII             70.666667    0.355556     28.977778     0.000000
# X                86.119554    0.000000     13.475177     0.405268
# XI               78.035471    0.136426     20.463847     1.364256
# XII              79.488546    0.745871     19.659030     0.106553
# XIII             77.141729    0.829056     21.989735     0.039479
# XIV              81.273408    0.124844     18.601748     0.000000
# XV               79.679144    0.356506     19.607843     0.356506

# %%
ax = df_listings_type.plot(
    kind='bar',
    stacked=True,
    figsize=(12,6),
    cmap="tab10"
)

plt.title("Percentage of Room Types by Neighborhood", fontsize=18)
plt.ylabel("Percentage (%)", fontsize=14)
plt.xlabel("Neighborhood (District Number)", fontsize=14)

# Rotate labels in X-Axis
plt.xticks(fontsize=12, rotation=0) # rotation=0 keeps them horizontal

plt.legend(title='Room Type', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=11) # Move legend outside
plt.tight_layout()
plt.savefig("2-1.png")
plt.show()

# %%
df_listings_renter_type = df_listings["renter_type"].value_counts()
df_listings_renter_type
# Out:
# renter_type
# business    21172
# casual      14066
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
colors = ['#8da0cb', '#fc8d62']

sns.barplot(
    x=df_listings_renter_type.index, 
    y=df_listings_renter_type.values, 
    palette=colors,
    hue=df_listings_renter_type.values,
    order=["business", "casual"]
)

plt.xlabel("Renter Type")
plt.ylabel("Number of Listings")
plt.title('Market Dominance - Who owns the listings?', fontsize=16)
plt.savefig("2-2.png")
plt.show()

# %%
# plt.figure(figsize=(8, 8))

# # We use countplot because we are counting how many listings belong to each group
# ax = sns.countplot(
#     data=df_listings, 
#     x='renter_type', 
#     order=["business", "casual"],
#     hue='renter_type',
#     palette=colors,
#     legend=False
# )

# %%
df_listings_renter_type = df_listings.drop_duplicates(subset=['host_id'])
df_listings_renter_type = df_listings_renter_type["renter_type"].value_counts()
df_listings_renter_type
# Out:
# renter_type
# casual      14066
# business     5159
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))

colors = ['#fc8d62', '#8da0cb']

sns.barplot(
    x=df_listings_renter_type.index, 
    y=df_listings_renter_type.values, 
    palette=colors,
    hue=df_listings_renter_type.values,
    order=["business", "casual"]
)

plt.xlabel("Renter Type")
plt.ylabel("Number of Hosts")
plt.title('Casuals vs Businesses', fontsize=16)
plt.savefig("2-3.png")
plt.show()

# %% [markdown]
# ## 3. How does host type correlate with availability and legal compliance?

# %%
df_listings["has_license"] = df_listings["license"].notna()
df_listings[["id", "name", "host_id", "host_name", "license", "has_license"]]
# Out:
# /tmp/ipykernel_2410/1399967859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listings["has_license"] = df_listings["license"].notna()
#                         id                                               name  \
# 0                     2737                   Elif's room in cozy, clean flat.
# 1                    11834                    Charming Boschetto Studio, Rome
# 2                    12398                Casa Donatello - Home far from Home
# 3                    19965  S. Peter's Square 5 Min WALK bright and quite ...
# 4                    19967  *In front Vatican Museums 2 bedrooms quite bri...
# ...                    ...                                                ...
# 37647  1508816683242128286                    Residence Apartment Lucky Stars
# 37648  1509264731966854270                            The Quirinale apartment
# 37649  1509322278066021169   Appartamento 3 camere, 3 bagni, balconi e cucina
# 37650  1509392114869132219                          appartamento residenziale
# 37651  1509455305653425509                             Bedroom Sweet Vaticano
#
#          host_id host_name             license  has_license
# 0           3047      Elif                 NaN        False
# 1          44552    Serena  IT058091C29VJSIZQZ         True
# 2          11756       Gea  it058091c2kv6epw8f         True
# 3          75450   Sabrina  IT058091C20YD35BX2         True
# 4          75450   Sabrina  IT058091C20YD35BX2         True
# ...          ...       ...                 ...          ...
# 37647  554023719     Lucky  IT058091B4XPH449TB         True
# 37648  718755020     David  IT058091C2RGTLCJNR         True
# 37649    9403439    Andrea  IT058091C2DZHIDY6A         True
# 37650  579802615  Domenico  it058091c2rf3ps25z         True
# 37651  357232108    Miriam  IT058091C26JO2EDQQ         True
#
# [35238 rows x 6 columns]

# %%
df_listings_license = round(df_listings.groupby(by="renter_type")["has_license"].mean() * 100, 3)
df_listings_license
# Out:
# renter_type
# business    95.593
# casual      93.090
# Name: has_license, dtype: float64

# %%
fig, axes = plt.subplots(2,1, figsize=(6, 10))
colors = ['#fc8d62', '#8da0cb']

# Plot Availability
sns.boxplot(
    data=df_listings, 
    x='renter_type', 
    y='availability_365', 
    ax=axes[0], 
    palette=colors,
    hue='renter_type',
    order=['business', 'casual'],
)
axes[0].set_title("Availability: Casual vs. Business", fontsize=14)
axes[0].set_ylabel("Days Available per Year")

# Plot Legal Compliance
sns.barplot(
    x=df_listings_license.index, 
    y=df_listings_license.values, 
    ax=axes[1], 
    palette=colors,
    hue=df_listings_license.index,
    order=['business', 'casual']
)
axes[1].set_title("Legal Compliance: % of Listings with License", fontsize=14)
axes[1].set_ylabel("% Licensed")
axes[1].set_ylim(0, 100)

for i, p in enumerate(df_listings_license):
    axes[1].text(i, p + 2, f'{p:.1f}%', ha='center')

plt.tight_layout()
plt.savefig("3-1.png")
plt.show()
